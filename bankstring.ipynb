# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthikaraja08/ruthika/blob/main/bankstring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/bank_customer_data.csv")

# %%
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  SANthosh Chevuri  SANTHOSH@GMAIL.COM   hdfc bank      savings
# 1        RAJU kumar      RAJU@YAHOO.COM  ICICI BANK      CURRENT
# 2       kiran REDDY     KIRAN@GMAIL.COM   axis bank       salary
# 3       SURESH BABU  SURESH@OUTLOOK.COM         SBI      SAVINGS
# 4      Lakshmi devi   LAKSHMI@GMAIL.COM  kotak bank      current
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000       vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
df["customer_name"]=df["customer_name"].str.title()
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  Santhosh Chevuri  SANTHOSH@GMAIL.COM   hdfc bank      savings
# 1        Raju Kumar      RAJU@YAHOO.COM  ICICI BANK      CURRENT
# 2       Kiran Reddy     KIRAN@GMAIL.COM   axis bank       salary
# 3       Suresh Babu  SURESH@OUTLOOK.COM         SBI      SAVINGS
# 4      Lakshmi Devi   LAKSHMI@GMAIL.COM  kotak bank      current
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000       vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
df["email"]=df["email"].str.lower()
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  Santhosh Chevuri  santhosh@gmail.com   hdfc bank      savings
# 1        Raju Kumar      raju@yahoo.com  ICICI BANK      CURRENT
# 2       Kiran Reddy     kiran@gmail.com   axis bank       salary
# 3       Suresh Babu  suresh@outlook.com         SBI      SAVINGS
# 4      Lakshmi Devi   lakshmi@gmail.com  kotak bank      current
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000       vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
df["bank_name"]=df["bank_name"].str.upper()
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  Santhosh Chevuri  santhosh@gmail.com   HDFC BANK      savings
# 1        Raju Kumar      raju@yahoo.com  ICICI BANK      CURRENT
# 2       Kiran Reddy     kiran@gmail.com   AXIS BANK       salary
# 3       Suresh Babu  suresh@outlook.com         SBI      SAVINGS
# 4      Lakshmi Devi   lakshmi@gmail.com  KOTAK BANK      current
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000       vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
df["account_type"]=df["account_type"].str.upper()
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  Santhosh Chevuri  santhosh@gmail.com   HDFC BANK      SAVINGS
# 1        Raju Kumar      raju@yahoo.com  ICICI BANK      CURRENT
# 2       Kiran Reddy     kiran@gmail.com   AXIS BANK       SALARY
# 3       Suresh Babu  suresh@outlook.com         SBI      SAVINGS
# 4      Lakshmi Devi   lakshmi@gmail.com  KOTAK BANK      CURRENT
#
#   account_number      balance branch_city
# 0       ACC-1001  Rs 1,25,000   hyderabad
# 1       ACC-1002       $2,500  VIJAYAWADA
# 2       ACC-1003    Rs 75,000       vizag
# 3       ACC-1004      $10,000      GUNTUR
# 4       ACC-1005    Rs 50,500    tirupati

# %%
df["balance"]=df["balance"].str.replace("Rs ","", regex= False)
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  Santhosh Chevuri  santhosh@gmail.com   HDFC BANK      SAVINGS
# 1        Raju Kumar      raju@yahoo.com  ICICI BANK      CURRENT
# 2       Kiran Reddy     kiran@gmail.com   AXIS BANK       SALARY
# 3       Suresh Babu  suresh@outlook.com         SBI      SAVINGS
# 4      Lakshmi Devi   lakshmi@gmail.com  KOTAK BANK      CURRENT
#
#   account_number   balance branch_city
# 0       ACC-1001  1,25,000   hyderabad
# 1       ACC-1002    $2,500  VIJAYAWADA
# 2       ACC-1003    75,000       vizag
# 3       ACC-1004   $10,000      GUNTUR
# 4       ACC-1005    50,500    tirupati

# %%
df["balance"]=df["balance"].str.replace("$","", regex= False)
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  Santhosh Chevuri  santhosh@gmail.com   HDFC BANK      SAVINGS
# 1        Raju Kumar      raju@yahoo.com  ICICI BANK      CURRENT
# 2       Kiran Reddy     kiran@gmail.com   AXIS BANK       SALARY
# 3       Suresh Babu  suresh@outlook.com         SBI      SAVINGS
# 4      Lakshmi Devi   lakshmi@gmail.com  KOTAK BANK      CURRENT
#
#   account_number balance branch_city  username                 domain  \
# 0           1001  125000   hyderabad  santhosh  [santhosh, gmail.com]
# 1           1002    2500  VIJAYAWADA      raju      [raju, yahoo.com]
# 2           1003   75000       vizag     kiran     [kiran, gmail.com]
# 3           1004   10000      GUNTUR    suresh  [suresh, outlook.com]
# 4           1005   50500    tirupati   lakshmi   [lakshmi, gmail.com]
#
#   branch_code
# 0         hyd
# 1         VIJ
# 2         viz
# 3         GUN
# 4         tir

# %%
df["balance"]=df["balance"].str.replace(",","", regex= False)
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  Santhosh Chevuri  santhosh@gmail.com   HDFC BANK      SAVINGS
# 1        Raju Kumar      raju@yahoo.com  ICICI BANK      CURRENT
# 2       Kiran Reddy     kiran@gmail.com   AXIS BANK       SALARY
# 3       Suresh Babu  suresh@outlook.com         SBI      SAVINGS
# 4      Lakshmi Devi   lakshmi@gmail.com  KOTAK BANK      CURRENT
#
#   account_number balance branch_city  username                 domain  \
# 0           1001  125000   hyderabad  santhosh  [santhosh, gmail.com]
# 1           1002   $2500  VIJAYAWADA      raju      [raju, yahoo.com]
# 2           1003   75000       vizag     kiran     [kiran, gmail.com]
# 3           1004  $10000      GUNTUR    suresh  [suresh, outlook.com]
# 4           1005   50500    tirupati   lakshmi   [lakshmi, gmail.com]
#
#   branch_code
# 0         hyd
# 1         VIJ
# 2         viz
# 3         GUN
# 4         tir

# %%
df["balance"]=df['balance'].astype(int)
df
# Out:
#       customer_name               email   bank_name account_type  \
# 0  Santhosh Chevuri  santhosh@gmail.com   HDFC BANK      SAVINGS
# 1        Raju Kumar      raju@yahoo.com  ICICI BANK      CURRENT
# 2       Kiran Reddy     kiran@gmail.com   AXIS BANK       SALARY
# 3       Suresh Babu  suresh@outlook.com         SBI      SAVINGS
# 4      Lakshmi Devi   lakshmi@gmail.com  KOTAK BANK      CURRENT
#
#   account_number  balance branch_city  username                 domain  \
# 0           1001   125000   hyderabad  santhosh  [santhosh, gmail.com]
# 1           1002     2500  VIJAYAWADA      raju      [raju, yahoo.com]
# 2           1003    75000       vizag     kiran     [kiran, gmail.com]
# 3           1004    10000      GUNTUR    suresh  [suresh, outlook.com]
# 4           1005    50500    tirupati   lakshmi   [lakshmi, gmail.com]
#
#   branch_code
# 0         hyd
# 1         VIJ
# 2         viz
# 3         GUN
# 4         tir

# %%
df["username"]=df["email"].str.split("@").str[0]
df

# %%
df["domain"]=df["email"].str.split("@")
df

# %%
df["branch_code"]=df["branch_city"].str[:3]
df

# %%
df["account_number"]=df["account_number"].str.removeprefix("ACC-")
df
