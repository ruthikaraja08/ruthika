# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthikaraja08/ruthika/blob/main/matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
mat=np.array([
    [1,2],
    [3,4]
])
print(np.linalg.det(mat))
# Out:
# -2.0000000000000004

# %%
mat=np.array([
    [1,2],
    [3,4]
])
print(np.linalg.inv(mat))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]
