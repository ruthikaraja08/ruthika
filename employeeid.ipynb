# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthikaraja08/ruthika/blob/main/employeeid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/employee_attendance.csv")
df
# Out:
#   employee_name  login_date login_time  working_hours
# 0          Ravi  2024-02-10    8:45:30              8
# 1         Priya  2024-03-15    9:10:15              9
# 2       Karthik  2024-05-20    8:55:45              8
# 3        Anjali  2024-07-08    9:25:10              7
# 4        Vikram  2024-11-25    8:30:20              9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   employee_name  5 non-null      object
#  1   login_date     5 non-null      object
#  2   login_time     5 non-null      object
#  3   working_hours  5 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
df["login_date"]=pd.to_datetime(df["login_date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   employee_name  5 non-null      object
#  1   login_date     5 non-null      datetime64[ns]
#  2   login_time     5 non-null      object
#  3   working_hours  5 non-null      int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df["year"]=df["login_date"].dt.year
df["month"]=df["login_date"].dt.month
df["day"]=df["login_date"].dt.day
df
# Out:
#   employee_name login_date login_time  working_hours  year  month  day
# 0          Ravi 2024-02-10    8:45:30              8  2024      2   10
# 1         Priya 2024-03-15    9:10:15              9  2024      3   15
# 2       Karthik 2024-05-20    8:55:45              8  2024      5   20
# 3        Anjali 2024-07-08    9:25:10              7  2024      7    8
# 4        Vikram 2024-11-25    8:30:20              9  2024     11   25

# %%
df["month_name"]=df["login_date"].dt.month_name()
df
# Out:
#   employee_name login_date login_time  working_hours  year  month  day  \
# 0          Ravi 2024-02-10    8:45:30              8  2024      2   10
# 1         Priya 2024-03-15    9:10:15              9  2024      3   15
# 2       Karthik 2024-05-20    8:55:45              8  2024      5   20
# 3        Anjali 2024-07-08    9:25:10              7  2024      7    8
# 4        Vikram 2024-11-25    8:30:20              9  2024     11   25
#
#   month_name
# 0   February
# 1      March
# 2        May
# 3       July
# 4   November

# %%
df["day_name"]=df["login_date"].dt.day_name()
df
# Out:
#   employee_name login_date login_time  working_hours  year  month  day  \
# 0          Ravi 2024-02-10    8:45:30              8  2024      2   10
# 1         Priya 2024-03-15    9:10:15              9  2024      3   15
# 2       Karthik 2024-05-20    8:55:45              8  2024      5   20
# 3        Anjali 2024-07-08    9:25:10              7  2024      7    8
# 4        Vikram 2024-11-25    8:30:20              9  2024     11   25
#
#   month_name  day_name
# 0   February  Saturday
# 1      March    Friday
# 2        May    Monday
# 3       July    Monday
# 4   November    Monday

# %%
df["hour"]=df["login_time"].dt.hour
df["minute"]=df["login_time"].dt.minute
df["seconds"]=df["login_time"].dt.second
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3602/2517346179.py in <cell line: 0>()
# ----> 1 df["hour"]=df["login_time"].dt.hour
#       2 df["minute"]=df["login_time"].dt.minute
#       3 df["seconds"]=df["login_time"].dt.second
#       4 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df["login_date"].min()
df
# Out:
#   employee_name login_date login_time  working_hours  year  month  day  \
# 0          Ravi 2024-02-10    8:45:30              8  2024      2   10
# 1         Priya 2024-03-15    9:10:15              9  2024      3   15
# 2       Karthik 2024-05-20    8:55:45              8  2024      5   20
# 3        Anjali 2024-07-08    9:25:10              7  2024      7    8
# 4        Vikram 2024-11-25    8:30:20              9  2024     11   25
#
#   month_name  day_name
# 0   February  Saturday
# 1      March    Friday
# 2        May    Monday
# 3       July    Monday
# 4   November    Monday

# %%
df["login_date"].max()
df
# Out:
#   employee_name login_date login_time  working_hours  year  month  day  \
# 0          Ravi 2024-02-10    8:45:30              8  2024      2   10
# 1         Priya 2024-03-15    9:10:15              9  2024      3   15
# 2       Karthik 2024-05-20    8:55:45              8  2024      5   20
# 3        Anjali 2024-07-08    9:25:10              7  2024      7    8
# 4        Vikram 2024-11-25    8:30:20              9  2024     11   25
#
#   month_name  day_name
# 0   February  Saturday
# 1      March    Friday
# 2        May    Monday
# 3       July    Monday
# 4   November    Monday

# %%
df["working_hours"].max()
# Out:
# 9
